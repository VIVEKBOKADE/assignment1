# %%
"""Q1. Explain why we have to use the Exception class while creating a Custom Exception."""

#It can make your code much more readable and robust, and reduce the amount of code you write later 
#to try and figure out what exactly went wrong.Using the custom exception, we can have your own exception and message.
# Out:
# 'Q1. Explain why we have to use the Exception class while creating a Custom Exception.'

# %%
"""Q2. Write a python program to print Python Exception Hierarchy."""

# import inspect module 
import inspect 

# our treeClass function 
def treeClass(cls, ind = 0): 
	
	# print name of the class 
	print ('-' * ind, cls.__name__) 
	
	# iterating through subclasses 
	for i in cls.__subclasses__(): 
		treeClass(i, ind + 3) 

print("Hierarchy for Built-in exceptions is : ") 

# inspect.getmro() Return a tuple 
# of class cls’s base classes. 

# building a tree hierarchy 
inspect.getclasstree(inspect.getmro(BaseException)) 

# function call 
treeClass(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %%
"""Q3. What errors are defined in the ArithmeticError class? Explain any two with an example."""

#ArithmeticError types in Python include: OverFlowError, ZeroDivisionError, FloatingPointError.

"""ZeroDivisionError"""
arithmetic = 5/0
print(arithmetic)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 #ArithmeticError types in Python include: OverFlowError, ZeroDivisionError, FloatingPointError.
#       5 """ZeroDivisionError"""
# ----> 6 arithmetic = 5/0
#       7 print(arithmetic)
#
# ZeroDivisionError: division by zero

# %%
"""OverFlowError"""
import math as m
print(m.exp(1000))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[19], line 3
#       1 """OverFlowError"""
#       2 import math as m
# ----> 3 print(m.exp(1000))
#
# OverflowError: math range error

# %%
"""Q4. Why LookupError class is used? Explain with an example KeyError and IndexError."""

#LookupError Exception is the Base class for errors raised when something can’t be found. The base class for the exceptions 
#that are raised when a key or index used on a mapping or sequence is invalid: IndexError, KeyError.
#An IndexError is raised when a sequence reference is out of range.
j = [1, 2, 4]
print(j[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 7
#       3 #LookupError Exception is the Base class for errors raised when something can’t be found. The base class for the exceptions
#       4 #that are raised when a key or index used on a mapping or sequence is invalid: IndexError, KeyError.
#       5 #An IndexError is raised when a sequence reference is out of range.
#       6 j = [1, 2, 4]
# ----> 7 print(j[4])
#
# IndexError: list index out of range

# %%
#KeyError
person_info = {
    'name': 'Satyam Tripathi',
    'age': 22,
    'city': 'Delhi, Bharat',
    'occupation': 'Freelance Writer',
    'is_student': False
}

print(person_info["Name"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 10
#       1 #KeyError
#       2 person_info = {
#       3     'name': 'Satyam Tripathi',
#       4     'age': 22,
#    (...)
#       7     'is_student': False
#       8 }
# ---> 10 print(person_info["Name"])
#
# KeyError: 'Name'

# %%
"""Q5. Explain ImportError. What is ModuleNotFoundError?"""

#In Python, ImportError occurs when the Python program tries to import module which does not exist in the private table. 
#ModuleNotFoundError is only raised when no module is found with that name, usually because the package is not installed.
import numpys as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 5
#       1 """Q5. Explain ImportError. What is ModuleNotFoundError?"""
#       3 #In Python, ImportError occurs when the Python program tries to import module which does not exist in the private table.
#       4 #ModuleNotFoundError is only raised when no module is found with that name, usually because the package is not installed.
# ----> 5 import numpys as np
#
# ModuleNotFoundError: No module named 'numpys'

# %%
"""Q6. List down some best practices for exception handling in python."""

#1. Use Specific Exceptions
#2. Implement Error Logging
#3. Define Custom Exception Classes
#4. Handle Exceptions Gracefully
#5. Use Finally for Cleanup Tasks
# Out:
# 'Q6. List down some best practices for exception handling in python.'
